# %%
# IMPORT LIBRARIES
import pandas as pd, numpy as np, os, gc

# LOAD AND FREQUENCY-ENCODE
FE = ['EngineVersion','AppVersion','AvSigVersion','Census_OSVersion']
# LOAD AND ONE-HOT-ENCODE
OHE = [ 'RtpStateBitfield','IsSxsPassiveMode','DefaultBrowsersIdentifier',
        'AVProductStatesIdentifier','AVProductsInstalled', 'AVProductsEnabled',
        'CountryIdentifier', 'CityIdentifier', 
        'GeoNameIdentifier', 'LocaleEnglishNameIdentifier',
        'Processor', 'OsBuild', 'OsSuite',
        'SmartScreen','Census_MDC2FormFactor',
        'Census_OEMNameIdentifier', 
        'Census_ProcessorCoreCount',
        'Census_ProcessorModelIdentifier', 
        'Census_PrimaryDiskTotalCapacity', 'Census_PrimaryDiskTypeName',
        'Census_HasOpticalDiskDrive',
        'Census_TotalPhysicalRAM', 'Census_ChassisTypeName',
        'Census_InternalPrimaryDiagonalDisplaySizeInInches',
        'Census_InternalPrimaryDisplayResolutionHorizontal',
        'Census_InternalPrimaryDisplayResolutionVertical',
        'Census_PowerPlatformRoleName', 'Census_InternalBatteryType',
        'Census_InternalBatteryNumberOfCharges',
        'Census_OSEdition', 'Census_OSInstallLanguageIdentifier',
        'Census_GenuineStateName','Census_ActivationChannel',
        'Census_FirmwareManufacturerIdentifier',
        'Census_IsTouchEnabled', 'Census_IsPenCapable',
        'Census_IsAlwaysOnAlwaysConnectedCapable', 'Wdft_IsGamer',
        'Wdft_RegionIdentifier']

# LOAD ALL AS CATEGORIES
dtypes = {}
for x in FE+OHE: dtypes[x] = 'category'
dtypes['MachineIdentifier'] = 'str'
dtypes['HasDetections'] = 'int8'

# LOAD CSV FILE
df_train = pd.read_csv('train.csv', usecols=dtypes.keys(), dtype=dtypes, nrows=100000)
print ('Loaded',len(df_train),'rows of TRAIN.CSV!')


# DOWNSAMPLE
sm = 100000
df_train = df_train.sample(sm)
print ('Only using',sm,'rows to train and validate')
x=gc.collect()
print(x)
# Out:
# Loaded 100000 rows of TRAIN.CSV!
# Only using 100000 rows to train and validate
# 4086

# %%
import math

# CHECK FOR NAN
def nan_check(x):
    if isinstance(x,float):
        if math.isnan(x):
            return True
    return False

# FREQUENCY ENCODING
def encode_FE(df,col,verbose=1):
    d = df[col].value_counts(dropna=False)
    
    n = col+"_FE"
    df[n] = df[col].map(d)/d.max()
    
    if verbose==1:
        print('FE encoded',col)
    return [n]

# ONE-HOT-ENCODE ALL CATEGORY VALUES THAT COMPRISE MORE THAN
# "FILTER" PERCENT OF TOTAL DATA AND HAS SIGNIFICANCE GREATER THAN "ZVALUE"
def encode_OHE(df, col, filter, zvalue, tar='HasDetections', m=0.5, verbose=1):
    cv = df[col].value_counts(dropna=False)
    cvd = cv.to_dict()
    vals = len(cv)
    th = filter * len(df)
    sd = zvalue * 0.5/ math.sqrt(th)
    #print(sd)
    n = []; ct = 0; d = {}
    for x in cv.index:
        try:
            if cv[x]<th: break
            sd = zvalue * 0.5/ math.sqrt(cv[x])
        except:
            if cvd[x]<th: break
            sd = zvalue * 0.5/ math.sqrt(cvd[x])
        if nan_check(x): r = df[df[col].isna()][tar].mean()
        else: r = df[df[col]==x][tar].mean()
        if abs(r-m)>sd:
            nm = col+'_BE_'+str(x)
            if nan_check(x): df[nm] = (df[col].isna()).astype('int8')
            else: df[nm] = (df[col]==x).astype('int8')
            n.append(nm)
            d[x] = 1
        ct += 1
        if (ct+1)>=vals: break
    if verbose==1:
        print('OHE encoded',col,'- Created',len(d),'booleans')
    return [n,d]

# ONE-HOT-ENCODING from dictionary
def encode_OHE_test(df,col,dt):
    n = []
    for x in dt: 
        n += encode_BE(df,col,x)
    return n

# BOOLEAN ENCODING
def encode_BE(df,col,val):
    n = col+"_BE_"+str(val)
    if nan_check(val):
        df[n] = df[col].isna()
    else:
        df[n] = df[col]==val
    df[n] = df[n].astype('int8')
    return [n]

# %%
cols = []; dd = []

# ENCODE NEW
for x in FE:
    out = encode_FE(df_train,x)
    cols += out
for x in OHE:
    tmp = encode_OHE(df_train,x,0.005,5)
    print("tmp:",tmp)
    cols += tmp[0]; dd.append(tmp[1])
print('Encoded',len(cols),'new variables')
print("cols:",cols)
print("dd:",dd)
# REMOVE OLD
for x in FE+OHE:
    del df_train[x]

#df_train.to_csv('my_csv_1L.csv', mode='a', header=True)

print('Removed original',len(FE+OHE),'variables')
x = gc.collect()
print(x)
# Out:
# FE encoded EngineVersion
# FE encoded AppVersion
# FE encoded AvSigVersion
# FE encoded Census_OSVersion
# OHE encoded RtpStateBitfield - Created 1 booleans
# tmp: [['RtpStateBitfield_BE_0'], {'0': 1}]
# OHE encoded IsSxsPassiveMode - Created 0 booleans
# tmp: [[], {}]
# OHE encoded DefaultBrowsersIdentifier - Created 0 booleans
# tmp: [[], {}]
# OHE encoded AVProductStatesIdentifier - Created 6 booleans
# tmp: [['AVProductStatesIdentifier_BE_53447', 'AVProductStatesIdentifier_BE_7945', 'AVProductStatesIdentifier_BE_62773', 'AVProductStatesIdentifier_BE_23657', 'AVProductStatesIdentifier_BE_49480', 'AVProductStatesIdentifier_BE_41571'], {'53447': 1, '7945': 1, '62773': 1, '23657': 1, '49480': 1, '41571': 1}]
# OHE encoded AVProductsInstalled - Created 3 booleans
# tmp: [['AVProductsInstalled_BE_1', 'AVProductsInstalled_BE_2', 'AVProductsInstalled_BE_3'], {'1': 1, '2': 1, '3': 1}]
# OHE encoded AVProductsEnabled - Created 1 booleans
# tmp: [['AVProductsEnabled_BE_2'], {'2': 1}]
# OHE encoded CountryIdentifier - Created 3 booleans
# tmp: [['CountryIdentifier_BE_89', 'CountryIdentifier_BE_214', 'CountryIdentifier_BE_95'], {'89': 1, '214': 1, '95': 1}]
# OHE encoded CityIdentifier - Created 2 booleans
# tmp: [['CityIdentifier_BE_61668', 'CityIdentifier_BE_58607'], {'61668': 1, '58607': 1}]
# OHE encoded GeoNameIdentifier - Created 2 booleans
# tmp: [['GeoNameIdentifier_BE_89', 'GeoNameIdentifier_BE_120'], {'89': 1, '120': 1}]
# OHE encoded LocaleEnglishNameIdentifier - Created 3 booleans
# tmp: [['LocaleEnglishNameIdentifier_BE_75', 'LocaleEnglishNameIdentifier_BE_88', 'LocaleEnglishNameIdentifier_BE_118'], {'75': 1, '88': 1, '118': 1}]
# OHE encoded Processor - Created 2 booleans
# tmp: [['Processor_BE_x64', 'Processor_BE_x86'], {'x64': 1, 'x86': 1}]
# OHE encoded OsBuild - Created 3 booleans
# tmp: [['OsBuild_BE_17134', 'OsBuild_BE_15063', 'OsBuild_BE_14393'], {'17134': 1, '15063': 1, '14393': 1}]
# OHE encoded OsSuite - Created 1 booleans
# tmp: [['OsSuite_BE_256'], {'256': 1}]
# OHE encoded SmartScreen - Created 3 booleans
# tmp: [['SmartScreen_BE_RequireAdmin', 'SmartScreen_BE_nan', 'SmartScreen_BE_ExistsNotSet'], {'RequireAdmin': 1, nan: 1, 'ExistsNotSet': 1}]
# OHE encoded Census_MDC2FormFactor - Created 3 booleans
# tmp: [['Census_MDC2FormFactor_BE_Desktop', 'Census_MDC2FormFactor_BE_Detachable', 'Census_MDC2FormFactor_BE_LargeTablet'], {'Desktop': 1, 'Detachable': 1, 'LargeTablet': 1}]
# OHE encoded Census_OEMNameIdentifier - Created 2 booleans
# tmp: [['Census_OEMNameIdentifier_BE_4589', 'Census_OEMNameIdentifier_BE_1980'], {'4589': 1, '1980': 1}]
# OHE encoded Census_ProcessorCoreCount - Created 5 booleans
# tmp: [['Census_ProcessorCoreCount_BE_2', 'Census_ProcessorCoreCount_BE_8', 'Census_ProcessorCoreCount_BE_12', 'Census_ProcessorCoreCount_BE_1', 'Census_ProcessorCoreCount_BE_6'], {'2': 1, '8': 1, '12': 1, '1': 1, '6': 1}]
# OHE encoded Census_ProcessorModelIdentifier - Created 5 booleans
# tmp: [['Census_ProcessorModelIdentifier_BE_2697', 'Census_ProcessorModelIdentifier_BE_1916', 'Census_ProcessorModelIdentifier_BE_1848', 'Census_ProcessorModelIdentifier_BE_3082', 'Census_ProcessorModelIdentifier_BE_1914'], {'2697': 1, '1916': 1, '1848': 1, '3082': 1, '1914': 1}]
# OHE encoded Census_PrimaryDiskTotalCapacity - Created 9 booleans
# tmp: [['Census_PrimaryDiskTotalCapacity_BE_953869', 'Census_PrimaryDiskTotalCapacity_BE_305245', 'Census_PrimaryDiskTotalCapacity_BE_244198', 'Census_PrimaryDiskTotalCapacity_BE_29820', 'Census_PrimaryDiskTotalCapacity_BE_114473', 'Census_PrimaryDiskTotalCapacity_BE_228936', 'Census_PrimaryDiskTotalCapacity_BE_152627', 'Census_PrimaryDiskTotalCapacity_BE_59640', 'Census_PrimaryDiskTotalCapacity_BE_29824'], {'953869': 1, '305245': 1, '244198': 1, '29820': 1, '114473': 1, '228936': 1, '152627': 1, '59640': 1, '29824': 1}]
# OHE encoded Census_PrimaryDiskTypeName - Created 2 booleans
# tmp: [['Census_PrimaryDiskTypeName_BE_UNKNOWN', 'Census_PrimaryDiskTypeName_BE_Unspecified'], {'UNKNOWN': 1, 'Unspecified': 1}]
# OHE encoded Census_HasOpticalDiskDrive - Created 0 booleans
# tmp: [[], {}]
# OHE encoded Census_TotalPhysicalRAM - Created 4 booleans
# tmp: [['Census_TotalPhysicalRAM_BE_8192', 'Census_TotalPhysicalRAM_BE_2048', 'Census_TotalPhysicalRAM_BE_16384', 'Census_TotalPhysicalRAM_BE_1024'], {'8192': 1, '2048': 1, '16384': 1, '1024': 1}]
# OHE encoded Census_ChassisTypeName - Created 3 booleans
# tmp: [['Census_ChassisTypeName_BE_Desktop', 'Census_ChassisTypeName_BE_Other', 'Census_ChassisTypeName_BE_Detachable'], {'Desktop': 1, 'Other': 1, 'Detachable': 1}]
# OHE encoded Census_InternalPrimaryDiagonalDisplaySizeInInches - Created 7 booleans
# tmp: [['Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_13.9', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_11.6', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_13.3', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_10.1', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_27', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_15.4', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_10'], {'13.9': 1, '11.6': 1, '13.3': 1, '10.1': 1, '27': 1, '15.4': 1, '10': 1}]
# OHE encoded Census_InternalPrimaryDisplayResolutionHorizontal - Created 3 booleans
# tmp: [['Census_InternalPrimaryDisplayResolutionHorizontal_BE_1920', 'Census_InternalPrimaryDisplayResolutionHorizontal_BE_1280', 'Census_InternalPrimaryDisplayResolutionHorizontal_BE_1024'], {'1920': 1, '1280': 1, '1024': 1}]
# OHE encoded Census_InternalPrimaryDisplayResolutionVertical - Created 4 booleans
# tmp: [['Census_InternalPrimaryDisplayResolutionVertical_BE_1080', 'Census_InternalPrimaryDisplayResolutionVertical_BE_800', 'Census_InternalPrimaryDisplayResolutionVertical_BE_1200', 'Census_InternalPrimaryDisplayResolutionVertical_BE_600'], {'1080': 1, '800': 1, '1200': 1, '600': 1}]
# OHE encoded Census_PowerPlatformRoleName - Created 2 booleans
# tmp: [['Census_PowerPlatformRoleName_BE_Desktop', 'Census_PowerPlatformRoleName_BE_Slate'], {'Desktop': 1, 'Slate': 1}]
# OHE encoded Census_InternalBatteryType - Created 1 booleans
# tmp: [['Census_InternalBatteryType_BE_lion'], {'lion': 1}]
# OHE encoded Census_InternalBatteryNumberOfCharges - Created 1 booleans
# tmp: [['Census_InternalBatteryNumberOfCharges_BE_4294967295'], {'4294967295': 1}]
# OHE encoded Census_OSEdition - Created 2 booleans
# tmp: [['Census_OSEdition_BE_Core', 'Census_OSEdition_BE_CoreSingleLanguage'], {'Core': 1, 'CoreSingleLanguage': 1}]
# OHE encoded Census_OSInstallLanguageIdentifier - Created 2 booleans
# tmp: [['Census_OSInstallLanguageIdentifier_BE_10', 'Census_OSInstallLanguageIdentifier_BE_5'], {'10': 1, '5': 1}]
# OHE encoded Census_GenuineStateName - Created 0 booleans
# tmp: [[], {}]
# OHE encoded Census_ActivationChannel - Created 1 booleans
# tmp: [['Census_ActivationChannel_BE_Volume:GVLK'], {'Volume:GVLK': 1}]
# OHE encoded Census_FirmwareManufacturerIdentifier - Created 5 booleans
# tmp: [['Census_FirmwareManufacturerIdentifier_BE_142', 'Census_FirmwareManufacturerIdentifier_BE_nan', 'Census_FirmwareManufacturerIdentifier_BE_513', 'Census_FirmwareManufacturerIdentifier_BE_127', 'Census_FirmwareManufacturerIdentifier_BE_803'], {'142': 1, nan: 1, '513': 1, '127': 1, '803': 1}]
# OHE encoded Census_IsTouchEnabled - Created 0 booleans
# tmp: [[], {}]
# OHE encoded Census_IsPenCapable - Created 0 booleans
# tmp: [[], {}]
# OHE encoded Census_IsAlwaysOnAlwaysConnectedCapable - Created 1 booleans
# tmp: [['Census_IsAlwaysOnAlwaysConnectedCapable_BE_1'], {'1': 1}]
# OHE encoded Wdft_IsGamer - Created 2 booleans
# tmp: [['Wdft_IsGamer_BE_0', 'Wdft_IsGamer_BE_1'], {'0': 1, '1': 1}]
# OHE encoded Wdft_RegionIdentifier - Created 2 booleans
# tmp: [['Wdft_RegionIdentifier_BE_1', 'Wdft_RegionIdentifier_BE_15'], {'1': 1, '15': 1}]
# Encoded 100 new variables
# cols: ['EngineVersion_FE', 'AppVersion_FE', 'AvSigVersion_FE', 'Census_OSVersion_FE', 'RtpStateBitfield_BE_0', 'AVProductStatesIdentifier_BE_53447', 'AVProductStatesIdentifier_BE_7945', 'AVProductStatesIdentifier_BE_62773', 'AVProductStatesIdentifier_BE_23657', 'AVProductStatesIdentifier_BE_49480', 'AVProductStatesIdentifier_BE_41571', 'AVProductsInstalled_BE_1', 'AVProductsInstalled_BE_2', 'AVProductsInstalled_BE_3', 'AVProductsEnabled_BE_2', 'CountryIdentifier_BE_89', 'CountryIdentifier_BE_214', 'CountryIdentifier_BE_95', 'CityIdentifier_BE_61668', 'CityIdentifier_BE_58607', 'GeoNameIdentifier_BE_89', 'GeoNameIdentifier_BE_120', 'LocaleEnglishNameIdentifier_BE_75', 'LocaleEnglishNameIdentifier_BE_88', 'LocaleEnglishNameIdentifier_BE_118', 'Processor_BE_x64', 'Processor_BE_x86', 'OsBuild_BE_17134', 'OsBuild_BE_15063', 'OsBuild_BE_14393', 'OsSuite_BE_256', 'SmartScreen_BE_RequireAdmin', 'SmartScreen_BE_nan', 'SmartScreen_BE_ExistsNotSet', 'Census_MDC2FormFactor_BE_Desktop', 'Census_MDC2FormFactor_BE_Detachable', 'Census_MDC2FormFactor_BE_LargeTablet', 'Census_OEMNameIdentifier_BE_4589', 'Census_OEMNameIdentifier_BE_1980', 'Census_ProcessorCoreCount_BE_2', 'Census_ProcessorCoreCount_BE_8', 'Census_ProcessorCoreCount_BE_12', 'Census_ProcessorCoreCount_BE_1', 'Census_ProcessorCoreCount_BE_6', 'Census_ProcessorModelIdentifier_BE_2697', 'Census_ProcessorModelIdentifier_BE_1916', 'Census_ProcessorModelIdentifier_BE_1848', 'Census_ProcessorModelIdentifier_BE_3082', 'Census_ProcessorModelIdentifier_BE_1914', 'Census_PrimaryDiskTotalCapacity_BE_953869', 'Census_PrimaryDiskTotalCapacity_BE_305245', 'Census_PrimaryDiskTotalCapacity_BE_244198', 'Census_PrimaryDiskTotalCapacity_BE_29820', 'Census_PrimaryDiskTotalCapacity_BE_114473', 'Census_PrimaryDiskTotalCapacity_BE_228936', 'Census_PrimaryDiskTotalCapacity_BE_152627', 'Census_PrimaryDiskTotalCapacity_BE_59640', 'Census_PrimaryDiskTotalCapacity_BE_29824', 'Census_PrimaryDiskTypeName_BE_UNKNOWN', 'Census_PrimaryDiskTypeName_BE_Unspecified', 'Census_TotalPhysicalRAM_BE_8192', 'Census_TotalPhysicalRAM_BE_2048', 'Census_TotalPhysicalRAM_BE_16384', 'Census_TotalPhysicalRAM_BE_1024', 'Census_ChassisTypeName_BE_Desktop', 'Census_ChassisTypeName_BE_Other', 'Census_ChassisTypeName_BE_Detachable', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_13.9', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_11.6', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_13.3', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_10.1', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_27', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_15.4', 'Census_InternalPrimaryDiagonalDisplaySizeInInches_BE_10', 'Census_InternalPrimaryDisplayResolutionHorizontal_BE_1920', 'Census_InternalPrimaryDisplayResolutionHorizontal_BE_1280', 'Census_InternalPrimaryDisplayResolutionHorizontal_BE_1024', 'Census_InternalPrimaryDisplayResolutionVertical_BE_1080', 'Census_InternalPrimaryDisplayResolutionVertical_BE_800', 'Census_InternalPrimaryDisplayResolutionVertical_BE_1200', 'Census_InternalPrimaryDisplayResolutionVertical_BE_600', 'Census_PowerPlatformRoleName_BE_Desktop', 'Census_PowerPlatformRoleName_BE_Slate', 'Census_InternalBatteryType_BE_lion', 'Census_InternalBatteryNumberOfCharges_BE_4294967295', 'Census_OSEdition_BE_Core', 'Census_OSEdition_BE_CoreSingleLanguage', 'Census_OSInstallLanguageIdentifier_BE_10', 'Census_OSInstallLanguageIdentifier_BE_5', 'Census_ActivationChannel_BE_Volume:GVLK', 'Census_FirmwareManufacturerIdentifier_BE_142', 'Census_FirmwareManufacturerIdentifier_BE_nan', 'Census_FirmwareManufacturerIdentifier_BE_513', 'Census_FirmwareManufacturerIdentifier_BE_127', 'Census_FirmwareManufacturerIdentifier_BE_803', 'Census_IsAlwaysOnAlwaysConnectedCapable_BE_1', 'Wdft_IsGamer_BE_0', 'Wdft_IsGamer_BE_1', 'Wdft_RegionIdentifier_BE_1', 'Wdft_RegionIdentifier_BE_15']
# dd: [{'0': 1}, {}, {}, {'53447': 1, '7945': 1, '62773': 1, '23657': 1, '49480': 1, '41571': 1}, {'1': 1, '2': 1, '3': 1}, {'2': 1}, {'89': 1, '214': 1, '95': 1}, {'61668': 1, '58607': 1}, {'89': 1, '120': 1}, {'75': 1, '88': 1, '118': 1}, {'x64': 1, 'x86': 1}, {'17134': 1, '15063': 1, '14393': 1}, {'256': 1}, {'RequireAdmin': 1, nan: 1, 'ExistsNotSet': 1}, {'Desktop': 1, 'Detachable': 1, 'LargeTablet': 1}, {'4589': 1, '1980': 1}, {'2': 1, '8': 1, '12': 1, '1': 1, '6': 1}, {'2697': 1, '1916': 1, '1848': 1, '3082': 1, '1914': 1}, {'953869': 1, '305245': 1, '244198': 1, '29820': 1, '114473': 1, '228936': 1, '152627': 1, '59640': 1, '29824': 1}, {'UNKNOWN': 1, 'Unspecified': 1}, {}, {'8192': 1, '2048': 1, '16384': 1, '1024': 1}, {'Desktop': 1, 'Other': 1, 'Detachable': 1}, {'13.9': 1, '11.6': 1, '13.3': 1, '10.1': 1, '27': 1, '15.4': 1, '10': 1}, {'1920': 1, '1280': 1, '1024': 1}, {'1080': 1, '800': 1, '1200': 1, '600': 1}, {'Desktop': 1, 'Slate': 1}, {'lion': 1}, {'4294967295': 1}, {'Core': 1, 'CoreSingleLanguage': 1}, {'10': 1, '5': 1}, {}, {'Volume:GVLK': 1}, {'142': 1, nan: 1, '513': 1, '127': 1, '803': 1}, {}, {}, {'1': 1}, {'0': 1, '1': 1}, {'1': 1, '15': 1}]
# Removed original 43 variables
# 842

# %%
from keras import callbacks
from sklearn.metrics import roc_auc_score

class printAUC(callbacks.Callback):
    def __init__(self, X_train, y_train):
        super(printAUC, self).__init__()
        self.bestAUC = 0
        self.X_train = X_train
        self.y_train = y_train
        
    def on_epoch_end(self, epoch, logs={}):
        pred = self.model.predict(np.array(self.X_train))
        auc = roc_auc_score(self.y_train, pred)
        print("Train AUC: " + str(auc))
        pred = self.model.predict(self.validation_data[0])
        auc = roc_auc_score(self.validation_data[1], pred)
        print ("Validation AUC: " + str(auc))
        if (self.bestAUC < auc) :
            self.bestAUC = auc
            self.model.save("bestNet.h5", overwrite=True)
        return

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, Activation
from keras.callbacks import LearningRateScheduler
from keras.optimizers import Adam

#SPLIT TRAIN AND VALIDATION SET
X_train, X_val, Y_train, Y_val = train_test_split(
    df_train[cols], df_train['HasDetections'], test_size = 0.5)

# BUILD MODEL
model = Sequential()
model.add(Dense(100,input_dim=len(cols)))
model.add(Dropout(0.4))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Dropout(0.4))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer=Adam(lr=0.01), loss="binary_crossentropy", metrics=["accuracy"])
annealer = LearningRateScheduler(lambda x: 1e-2 * 0.95 ** x)

# TRAIN MODEL
model.fit(X_train,Y_train, batch_size=32, epochs = 20, callbacks=[annealer,
          printAUC(X_train, Y_train)], validation_data = (X_val,Y_val), verbose=2)
# Out:
# WARNING:tensorflow:From C:\Users\hpatel8\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\hpatel8\appdata\local\programs\python\python37\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\hpatel8\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/20
#  - 1s - loss: 0.7780 - acc: 0.5190 - val_loss: 0.6849 - val_acc: 0.5380
# Train AUC: 0.6102957358184051
# Validation AUC: 0.5830361324255195
# Epoch 2/20
#  - 0s - loss: 0.7031 - acc: 0.5410 - val_loss: 0.6731 - val_acc: 0.5440
# Train AUC: 0.5931981962155739
# Validation AUC: 0.5822836237296412
# Epoch 3/20
#  - 0s - loss: 0.7068 - acc: 0.5300 - val_loss: 0.6708 - val_acc: 0.5460
# Train AUC: 0.6077629151845197
# Validation AUC: 0.5849214068710449
# Epoch 4/20
#  - 0s - loss: 0.6863 - acc: 0.5450 - val_loss: 0.6748 - val_acc: 0.5440
# Train AUC: 0.5994402186308363
# Validation AUC: 0.571336223286942
# Epoch 5/20
#  - 0s - loss: 0.6853 - acc: 0.5590 - val_loss: 0.6745 - val_acc: 0.5440
# Train AUC: 0.6055622021534977
# Validation AUC: 0.5751147775896506
# Epoch 6/20
#  - 0s - loss: 0.6863 - acc: 0.5610 - val_loss: 0.6816 - val_acc: 0.5480
# Train AUC: 0.6044978573057671
# Validation AUC: 0.5803903438724578
# Epoch 7/20
#  - 0s - loss: 0.7011 - acc: 0.5160 - val_loss: 0.6729 - val_acc: 0.5440
# Train AUC: 0.6105038032322473
# Validation AUC: 0.5832843001869263
# Epoch 8/20
#  - 0s - loss: 0.6829 - acc: 0.5390 - val_loss: 0.6693 - val_acc: 0.5550
# Train AUC: 0.6050420336188925
# Validation AUC: 0.5903170543287263
# Epoch 9/20
#  - 0s - loss: 0.6720 - acc: 0.5650 - val_loss: 0.6662 - val_acc: 0.5440
# Train AUC: 0.6052621049219946
# Validation AUC: 0.5889801505817933
# Epoch 10/20
#  - 0s - loss: 0.6854 - acc: 0.5430 - val_loss: 0.6693 - val_acc: 0.5540
# Train AUC: 0.6045018586021871
# Validation AUC: 0.5840207980594881
# Epoch 11/20
#  - 0s - loss: 0.6780 - acc: 0.5690 - val_loss: 0.6711 - val_acc: 0.5390
# Train AUC: 0.6074027985067161
# Validation AUC: 0.5831281946595899
# Epoch 12/20
#  - 0s - loss: 0.6829 - acc: 0.5260 - val_loss: 0.6684 - val_acc: 0.5400
# Train AUC: 0.6065945366298681
# Validation AUC: 0.5838486817088352
# Epoch 13/20
#  - 0s - loss: 0.6717 - acc: 0.5680 - val_loss: 0.6723 - val_acc: 0.5370
# Train AUC: 0.6108079017601702
# Validation AUC: 0.5757211875227654
# Epoch 14/20
#  - 0s - loss: 0.6744 - acc: 0.5640 - val_loss: 0.6711 - val_acc: 0.5410
# Train AUC: 0.6141889972351042
# Validation AUC: 0.5820394586740636
# Epoch 15/20
#  - 0s - loss: 0.6806 - acc: 0.5620 - val_loss: 0.6708 - val_acc: 0.5400
# Train AUC: 0.6071467155358337
# Validation AUC: 0.5815751447978834
# Epoch 16/20
#  - 0s - loss: 0.6753 - acc: 0.5490 - val_loss: 0.6694 - val_acc: 0.5350
# Train AUC: 0.6071107038680532
# Validation AUC: 0.5816031637386874
# Epoch 17/20
#  - 0s - loss: 0.6728 - acc: 0.5750 - val_loss: 0.6684 - val_acc: 0.5410
# Train AUC: 0.6014288629515964
# Validation AUC: 0.583700581593157
# Epoch 18/20
#  - 0s - loss: 0.6737 - acc: 0.5620 - val_loss: 0.6702 - val_acc: 0.5420
# Train AUC: 0.6102997371148252
# Validation AUC: 0.5792855970636149
# Epoch 19/20
#  - 0s - loss: 0.6758 - acc: 0.5580 - val_loss: 0.6721 - val_acc: 0.5430
# Train AUC: 0.6091593676351138
# Validation AUC: 0.5793936701210018
# Epoch 20/20
#  - 0s - loss: 0.6739 - acc: 0.5610 - val_loss: 0.6708 - val_acc: 0.5400
# Train AUC: 0.6072547505391747
# Validation AUC: 0.5795817972949714

# %%
# del df_train
# del X_train, X_val, Y_train, Y_val
x = gc.collect()

# LOAD BEST SAVED NET
from keras.models import load_model
model = load_model('bestNet.h5')

pred = np.zeros((7853253,1))
id = 1
chunksize = 2000000
for df_test in pd.read_csv('test.csv', 
            chunksize = chunksize, usecols=list(dtypes.keys())[0:-1], dtype=dtypes):
    print ('Loaded',len(df_test),'rows of TEST.CSV!')
    # ENCODE TEST
    cols = []
    for x in FE:
        cols += encode_FE(df_test,x,verbose=0)
    for x in range(len(OHE)):
        cols += encode_OHE_test(df_test,OHE[x],dd[x])
    # PREDICT TEST
    end = (id)*chunksize
    if end>7853253: end = 7853253
    pred[(id-1)*chunksize:end] = model.predict(df_test[cols])
    print('  encoded and predicted part',id)
    id += 1
# Out:
# Loaded 2000000 rows of TEST.CSV!
#   encoded and predicted part 1
# Loaded 2000000 rows of TEST.CSV!
#   encoded and predicted part 2
# Loaded 2000000 rows of TEST.CSV!
#   encoded and predicted part 3
# Loaded 1853253 rows of TEST.CSV!
#   encoded and predicted part 4

# %%
# SUBMIT TO KAGGLE
df_test = pd.read_csv('test.csv', usecols=['MachineIdentifier'])
df_test['HasDetections'] = pred
df_test.to_csv('submission.csv', index=False)
